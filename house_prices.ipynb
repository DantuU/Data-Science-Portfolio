# %%
import pandas as pd

# %%
# Leemos el archivo
pd.read_csv('train.csv')

# Mostramos las primeras 5 lineas
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Leemos el archivo
# ----> 2 pd.read_csv(train (1))
#       4 # Mostramos las primeras 5 lineas
#       5 df.head()
#
# NameError: name 'train' is not defined
